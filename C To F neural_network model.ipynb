# %% [markdown]
# <b>it is a simple celsius_to_fahrenheit neural network model with only one layer of neurons

# %%
#import of libraries 
import tensorflow as tf
import keras as k
import numpy as np

# %%
#here is data given for model training 
#here Celsius is feature
#here fahernheite is target
celsius   = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

# %% [markdown]
# ## Build a layer
#
# We'll call the layer `l0` and create it by instantiating `tf.keras.layers.Dense` with the following configuration:
#
# *   `input_shape=[1]` — This specifies that the input to this layer is a single value. That is, the shape is a one-dimensional array with one member. Since this is the first (and only) layer, that input shape is the input shape of the entire model. The single value is a floating point number, representing degrees Celsius.
#
# *   `units=1` — This specifies the number of neurons in the layer. The number of neurons defines how many internal variables the layer has to try to learn how to solve the problem (more later). Since this is the final layer, it is also the size of the model's output — a single float value representing degrees Fahrenheit. (In a multi-layered network, the size and shape of the layer would need to match the `input_shape` of the next layer.)

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
#here we impelement the layer
model = tf.keras.Sequential([l0])

# %%
#here we complile the model 
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
#fitting of the data in model
history = model.fit(celsius,fahrenheit,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7947
# Epoch 2/500
# 1/1 [==============================] - 0s 0s/step - loss: 6.6995
# Epoch 3/500
# 1/1 [==============================] - 0s 0s/step - loss: 6.6055
# Epoch 4/500
# 1/1 [==============================] - 0s 0s/step - loss: 6.5127
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.4210
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3306
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2413
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.1532
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.0663
# Epoch 10/500
# 1/1 [==============================] - 0s 0s/step - loss: 5.9804
# Epoch 11/500
# 1/1 [==============================] - 0s 0s/step - loss: 5.8957
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.8121
# Epoch 13/500
# ...

# %%
#here we plot epoch no v/s Loss 
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %%
#here we do predictions
c = float(input("Enter Celecious"))
print("{} `C = {} 'f'".format(c,model.predict([c])))
# Out:
# Enter Celecious2
# 2.0 `C = [[35.526836]] 'f'
